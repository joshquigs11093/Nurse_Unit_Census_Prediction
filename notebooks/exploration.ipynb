# %%
import sys
sys.path.append('../src')
from utils.dataloader import query_to_df ## Load data from SQL server

# %% [markdown]
# Read from query file

# %%
with open("../census_ml_dataset.sql", "r") as f:
    sql = f.read()

# %%
df = query_to_df(sql,"mart")

# %%
df.to_csv('../data/raw/postsql.csv')
